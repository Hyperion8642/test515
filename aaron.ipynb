# %%
import random
prob = 0.00001

if (random.random() < prob):
    print("You got an internship")
else:
    print("Dear [name],\nThank you for your interest in joining company.\nWe appreciate the time and effort you put into your application for the Data Science Internship (Summer 2026) role.\nAfter careful consideration, we have decided to move forward with other candidates whose qualifications more closely align with our current needs.\nWe encourage you to continue pursuing opportunities that align with your goals and if a suitable position at company opens up again, we would be happy to hear from you and consider your application!")
# Out:
# Dear [name],
# Thank you for your interest in joining company.
# We appreciate the time and effort you put into your application for the Data Science Internship (Summer 2026) role.
# After careful consideration, we have decided to move forward with other candidates whose qualifications more closely align with our current needs.
# We encourage you to continue pursuing opportunities that align with your goals and if a suitable position at company opens up again, we would be happy to hear from you and consider your application!
